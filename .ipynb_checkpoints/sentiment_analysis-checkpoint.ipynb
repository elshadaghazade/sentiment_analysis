# %%
import json as js
import pandas as pd
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2

# %%
json_data = None
data = pd.read_csv('./Sentiment-Analysis-Dataset/Sentiment Analysis Dataset.csv', error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-ab6484f00735> in <module>
#       1 json_data = None
# ----> 2 data = pd.read_csv('./Sentiment-Analysis-Dataset/new_ds.csv', error_bad_lines=False)
#
# ~/Documents/jupyter_notebooks/nltk/.py3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/Documents/jupyter_notebooks/nltk/.py3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/Documents/jupyter_notebooks/nltk/.py3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/Documents/jupyter_notebooks/nltk/.py3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at line 1396318

# %%
stemmer = SnowballStemmer('english')
with open("stopwords.txt", "r") as f:
    words = list(f)
    
data
# Out:
#             2-faced  -1
# 0           2-faces  -1
# 1          abnormal  -1
# 2           abolish  -1
# 3        abominable  -1
# 4        abominably  -1
# 5         abominate  -1
# 6       abomination  -1
# 7             abort  -1
# 8           aborted  -1
# 9            aborts  -1
# 10           abrade  -1
# 11         abrasive  -1
# 12           abrupt  -1
# 13         abruptly  -1
# 14          abscond  -1
# 15          absence  -1
# 16    absent-minded  -1
# 17         absentee  -1
# 18           absurd  -1
# 19        absurdity  -1
# 20         absurdly  -1
# 21       absurdness  -1
# 22            abuse  -1
# 23           abused  -1
# 24           abuses  -1
# 25          abusive  -1
# 26          abysmal  -1
# 27        abysmally  -1
# 28            abyss  -1
# 29       accidental  -1
# ...             ...  ..
# 6759          witty   1
# 6760            won   1
# 6761         wonder   1
# 6762      wonderful   1
# 6763    wonderfully   1
# 6764      wonderous   1
# 6765    wonderously   1
# 6766        wonders   1
# 6767       wondrous   1
# 6768            woo   1
# 6769           work   1
# 6770       workable   1
# 6771         worked   1
# 6772          works   1
# 6773   world-famous   1
# 6774          worth   1
# 6775    worth-while   1
# 6776     worthiness   1
# 6777     worthwhile   1
# 6778         worthy   1
# 6779            wow   1
# 6780          wowed   1
# 6781         wowing   1
# 6782           wows   1
# 6783            yay   1
# 6784       youthful   1
# 6785           zeal   1
# 6786         zenith   1
# 6787           zest   1
# 6788          zippy   1
#
# [6789 rows x 2 columns]
